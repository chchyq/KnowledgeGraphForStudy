# %% [markdown]
# ## Script to parse the html page: https://oyc.yale.edu/courses

# %%
# from html.parser import HTMLParser
from bs4 import BeautifulSoup
import urllib.request
from urllib.error import URLError, HTTPError
import pandas as pd
import csv
import pprint
import re
import os
from socket import timeout
import logging
import datetime
import subprocess

# %%
! conda env list
! conda list | grep urllib
# Out:
# # conda environments:
# #
#                          /home/connes-v/.platformio/penv
# base                  *  /home/connes-v/anaconda3
# deepnumpy                /home/connes-v/anaconda3/envs/deepnumpy
# tensorflow_cpu           /home/connes-v/anaconda3/envs/tensorflow_cpu
#
# urllib3                   1.24.2                   py37_0

# %%
lengths = {}
def get_length(filename):
    if filename == "http://FILENAME.mp4":
        print("without video")
        return None
    if filename in lengths:
        return lengths[filename]
    try:
        result = subprocess.run(["ffprobe", "-v", "error", "-show_entries",
                                 "format=duration", "-of",
                                 "json", filename],
                                capture_output=True)
#         if result.stderr:
#             logging.warning(f"{filename}: {result.stderr}")
        duration = float(json.loads(result.stdout)["format"]["duration"])
    except Exception as e:
        print(filename)
        print("returncode:", result.returncode)
        print("stdout:", result.stdout)
        print("stderr:",  result.stderr)
        print(result)
        raise e
    lengths[filename] = datetime.timedelta(seconds=duration)
    return lengths[filename]

# %%
url = "https://oyc.yale.edu/courses"
try:
    html_page = urllib.request.urlopen(url, timeout=600) # timeout in second
except (URLError, HTTPError) as error:
    logging.error('Data not retrieved because %s\nURL: %s', error, url)
except timeout as error:
    logging.error('socket timed out %s- URL %s', e, url)
else:
    logging.info('Access successful.')
soup = BeautifulSoup(html_page)

table = soup.find(class_="views-table cols-5")
# python3 just use th.text
headers = [th.text.strip() for th in table.select("tr th")]
headers[0] = "Category"
headers[2] = "Serie Name"

series_df = pd.DataFrame(data=[[td.text.strip() for td in row.find_all("td") if row]\
                                                                for row in table.select("tr")][1:],
                         columns=headers)

links = table.find_all("td", class_="views-field views-field-field-course-number")
urls = ["https://oyc.yale.edu" + link.a["href"] for link in links]

series_df.insert(value=pd.Series(list(urls), 
                 index=series_df.index),
                 column="Url",
                 loc=5)
series_df["Corpus"] = "yaleocw"

# %%
data, index = [], []

for sid, row in series_df.iterrows():
    print(f"[{sid + 1}/{series_df.shape[0]}]{row['Course Number']}:{row['Serie Name']}")
    url = row["Url"]
    try:
        html_page = urllib.request.urlopen(url)
        index.append(sid)
    except (HTTPError, AttributeError) as e:
        print("HTTPError:", sid, url)
        continue
    soup = BeautifulSoup(html_page)
    
    # recover author field
    author_subpart = soup.find("div", class_="views-field views-field-field-about-the-professor")
    author_name = author_subpart.select_one("b").string[6:]
    author_description = " ".join([p.text for p in author_subpart.select("p") if p]).strip()
    author = dict(name=author_name, description=author_description)
    
    # recover description field
    description = soup.find("span", string='About the Course', class_="views-label views-label-body").parent
    description = " ".join([p.text for p in description.select("p") if p]).strip()
    
    # recover course_struct field
    course_struct = soup.find("span", string='Course Structure',
                              class_="views-label views-label-field-course-structure").parent
    course_struct = " ".join([p.text for p in course_struct.select("p") if p]).strip()
    
    # recover material_url field
    material_url = soup.find("span", string='Course Materials',
                             class_="views-label views-label-field-course-download-link").parent
    material_url = material_url.select_one("a")["href"]
    
    # recover sessions field
    session_number = soup.find_all("td", class_="views-field views-field-field-session-display-number")
    session_number = [td.text.strip() for td in session_number if td]

    session_link = soup.find_all("td", class_="views-field views-field-field-session-display-title")
    session_link = ["https://oyc.yale.edu" + link.a["href"] for link in session_link]
    session_title = soup.find_all("td", class_="views-field views-field-field-session-display-title")
    session_title = [td.text.strip() for td in session_title if td]
    sessions = [dict(title=t, url=u, number=n) 
                         for t, u, n in zip(session_title, session_link, session_number)]
    
    # build the Series
    data.append([author, description, sessions, material_url, course_struct])
    
# Add to the dataframe
columns = ["Author", "Description", "Sessions", "Material Url", "Course Structure"]

series_df = pd.concat([series_df, pd.DataFrame(data=data, columns=columns, index=index)],
                       axis=1,
                       sort=False)
series_df.index.name = "Sid"
# Out:
# [1/40]AFAM 162:African American History: From Emancipation to the Present
# [2/40]AMST 246:Hemingway, Fitzgerald, Faulkner
# [3/40]ASTR 160:Frontiers and Controversies in Astrophysics
# [4/40]BENG 100:Frontiers of Biomedical Engineering
# [5/40]CHEM 125a:Freshman Organic Chemistry I
# [6/40]CHEM 125b:Freshman Organic Chemistry II
# [7/40]CLCV 205:Introduction to Ancient Greek History
# [8/40]EEB 122:Principles of Evolution, Ecology and Behavior
# [9/40]ECON 252:Financial Markets (2008)
# [10/40]ECON 252:Financial Markets (2011)
# [11/40]ECON 251:Financial Theory
# [12/40]ECON 159:Game Theory
# [13/40]ENGL 300:Introduction to Theory of Literature
# [14/40]ENGL 220:Milton
# [15/40]ENGL 310:Modern Poetry
# [16/40]ENGL 291:The American Novel Since 1945
# [17/40]EVST 255:Environmental Politics and Law
# [18/40]GG 140:The Atmosphere, the Ocean, and Environmental Change
# [19/40]HIST 116:The American Revolution
# [20/40]HIST 119:The Civil War and Reconstruction Era, 1845-1877
# [21/40]HIST 210:The Early Middle Ages, 284–1000
# [22/40]HIST 202:European Civilization, 1648-1945
# [23/40]HIST 234:Epidemics in Western Society Since 1600
# [24/40]HIST 251:Early Modern England: Politics, Religion, and Society under the Tudors and Stuarts
# [25/40]HIST 276:France Since 1871
# [26/40]HSAR 252:Roman Architecture
# [27/40]ITAL 310:Dante in Translation
# [28/40]MCDB 150:Global Problems of Population Growth
# [29/40]PHIL 181:Philosophy and the Science of Human Nature
# [30/40]PHIL 176:Death
# [31/40]PHYS 200:Fundamentals of Physics I
# [32/40]PHYS 201:Fundamentals of Physics II
# [33/40]PLSC 270:Capitalism: Success, Crisis, and Reform
# [34/40]PLSC 114:Introduction to Political Philosophy
# [35/40]PSYC 110:Introduction to Psychology
# [36/40]PSYC 123:The Psychology, Biology and Politics of Food
# [37/40]RLST 152:Introduction to the New Testament History and Literature
# [38/40]RLST 145:Introduction to the Old Testament (Hebrew Bible)
# [39/40]SOCY 151:Foundations of Modern Social Theory
# [40/40]SPAN 300:Cervantes' Don Quixote

# %%
print(series_df.shape)
series_df.head(10)
# series_df.loc[courses_df["Course Number"] == "ASTR 160"]
# Out:
# (40, 12)
#                              Category Course Number  \
# Sid
# 0            African American Studies      AFAM 162
# 1                    American Studies      AMST 246
# 2                           Astronomy      ASTR 160
# 3              Biomedical Engineering      BENG 100
# 4                           Chemistry     CHEM 125a
# 5                           Chemistry     CHEM 125b
# 6                            Classics      CLCV 205
# 7    Ecology and Evolutionary Biology       EEB 122
# 8                           Economics      ECON 252
# 9                           Economics      ECON 252
#
#                                             Serie Name      Professor Name  \
# Sid
# 0    African American History: From Emancipation to...   Jonathan Holloway
# 1                      Hemingway, Fitzgerald, Faulkner     Wai Chee Dimock
# 2          Frontiers and Controversies in Astrophysics      Charles Bailyn
# 3                  Frontiers of Biomedical Engineering    W. Mark Saltzman
# 4                         Freshman Organic Chemistry I  J. Michael McBride
# 5                        Freshman Organic Chemistry II  J. Michael McBride
# 6                Introduction to Ancient Greek History        Donald Kagan
# 7        Principles of Evolution, Ecology and Behavior  Stephen C. Stearns
# 8                             Financial Markets (2008)   Robert J. Shiller
# 9                             Financial Markets (2011)   Robert J. Shiller
#
#             Date                                                Url   Corpus  \
# Sid
# 0    Spring 2010  https://oyc.yale.edu/african-american-studies/...  yaleocw
# 1      Fall 2011     https://oyc.yale.edu/american-studies/amst-246  yaleocw
# 2    Spring 2007            https://oyc.yale.edu/astronomy/astr-160  yaleocw
# 3    Spring 2008  https://oyc.yale.edu/biomedical-engineering/be...  yaleocw
# 4      Fall 2008           https://oyc.yale.edu/chemistry/chem-125a  yaleocw
# 5    Spring 2011           https://oyc.yale.edu/chemistry/chem-125b  yaleocw
# 6      Fall 2007             https://oyc.yale.edu/classics/clcv-205  yaleocw
# 7    Spring 2009  https://oyc.yale.edu/ecology-and-evolutionary-...  yaleocw
# 8    Spring 2008         https://oyc.yale.edu/economics/econ-252-08  yaleocw
# 9    Spring 2011            https://oyc.yale.edu/economics/econ-252  yaleocw
#
#                                                 Author  \
# Sid
# 0    {'name': 'Professor Jonathan Holloway', 'descr...
# 1    {'name': 'Professor Wai Chee Dimock', 'descrip...
# 2    {'name': 'Professor Charles Bailyn', 'descript...
# 3    {'name': 'Professor W. Mark Saltzman', 'descri...
# 4    {'name': 'Professor J. Michael McBride', 'desc...
# 5    {'name': 'Professor J. Michael McBride', 'desc...
# 6    {'name': 'Professor Donald Kagan', 'descriptio...
# 7    {'name': 'Professor Stephen C. Stearns', 'desc...
# 8    {'name': 'Professor Robert J. Shiller', 'descr...
# 9    {'name': 'Professor Robert J. Shiller', 'descr...
#
#                                            Description  \
# Sid
# 0    The purpose of this course is to examine the A...
# 1    This course examines major works by Hemingway,...
# 2    This course focuses on three particularly inte...
# 3    The course covers basic concepts of biomedical...
# 4    This is the first semester in a two-semester i...
# 5    This is a continuation of Freshman Organic Che...
# 6    This is an introductory course in Greek histor...
# 7    This course presents the principles of evoluti...
# 8    Financial institutions are a pillar of civiliz...
# 9    An overview of the ideas, methods, and institu...
#
#                                               Sessions  \
# Sid
# 0    [{'title': 'Dawn of Freedom', 'url': 'https://...
# 1    [{'title': 'Introduction', 'url': 'https://oyc...
# 2    [{'title': 'Introduction', 'url': 'https://oyc...
# 3    [{'title': 'What Is Biomedical Engineering?', ...
# 4    [{'title': 'How Do You Know?', 'url': 'https:/...
# 5    [{'title': 'Mechanism: How Energies and Kineti...
# 6    [{'title': 'Introduction', 'url': 'https://oyc...
# 7    [{'title': 'The Nature of Evolution: Selection...
# 8    [{'title': 'Finance and Insurance as Powerful ...
# 9    [{'title': 'Introduction and What this Course ...
#
#                                           Material Url  \
# Sid
# 0    http://openmedia.yale.edu/cgi-bin/open_yale/me...
# 1    http://openmedia.yale.edu/cgi-bin/open_yale/me...
# 2    http://openmedia.yale.edu/cgi-bin/open_yale/me...
# 3    http://openmedia.yale.edu/cgi-bin/open_yale/me...
# 4    http://openmedia.yale.edu/cgi-bin/open_yale/me...
# 5    http://openmedia.yale.edu/cgi-bin/open_yale/me...
# 6    http://openmedia.yale.edu/cgi-bin/open_yale/me...
# 7    http://openmedia.yale.edu/cgi-bin/open_yale/me...
# 8    http://openmedia.yale.edu/cgi-bin/open_yale/me...
# 9    http://openmedia.yale.edu/cgi-bin/open_yale/me...
#
#                                       Course Structure
# Sid
# 0    This Yale College course, taught on campus twi...
# 1    This Yale College course, taught on campus two...
# 2    This Yale College course, taught on campus twi...
# 3    This Yale College course, taught on campus twi...
# 4    This Yale College course, taught on campus thr...
# 5    This Yale College course, taught on campus thr...
# 6    This Yale College course, taught on campus twi...
# 7    This Yale College course, taught on campus thr...
# 8    This Yale College course, taught on campus twi...
# 9    This Yale College course, taught on campus twi...

# %%
def create_row(sid, row, eid, d):
    periods, transcriptions, description, duration, video, resources = (None,) * 6
    try:
        url = d["url"]
        try:
            html_page = urllib.request.urlopen(url)
        except HTTPError as e:
            print("HTTPError:", eid, url)
        soup = BeautifulSoup(html_page)

        description = soup.find("div", 
                                class_="ds-1col node node-session node-promoted " +
                                       "view-mode-full node-published node-not-sticky " +
                                       "author-1 odd clearfix clearfix"
                               ).find_all("p")
        description = " ".join([p.text for p in description if p])

        resources = soup.find("aside", attrs={"aria-label": "Resources"})
        resources = [{"url": r["href"], "title": r["title"], "type": r["type"]} 
                             for r in resources.find_all("a")] if resources else None
        if soup.find("video"):
            video = {"url": soup.find("video").find("source")["src"],
                     "captions": soup.find("video").find("track")["src"]}
            duration = get_length(video["url"])
            selector = soup.find("td", class_="views-field " + "views-field-field-audio--file").a
            if selector :
                video["sound"] = selector["href"]
            selector = soup.find("td",
                                 class_="views-field " + "views-field-field-low-bandwidth-video-file").a
            if selector:
                video["low band"] = selector["href"]
            selector = soup.find("td",
                                 class_="views-field " + "views-field-field-high-bandwidth-video-file").a                 
            if selector:
                video["high band"] = selector["href"]

            tr = soup.find("h1", attrs={"id": "transcript-top"}).parent.find_all(string=True) 
            full_tr = "".join(tr).strip()
            match_list = list(re.finditer(r"(Chapter.*)\[(\d+\:\d+\:\d+)\]", full_tr))
            match_end = re.search(r"((?:\[end of transcripts?\])?\s*Back to Top)$", full_tr)
            has_chap = soup.find("h3", class_="label-above strong", string="Lecture Chapters")
            if has_chap:
                timestamps_a = []
                titles_a = [a.text for a in has_chap.parent.parent.find_all("a")]
                div_timestamps = has_chap.parent.parent.find_all("div", class_="views-field-field-chapter-start-time")
                for div in div_timestamps:
                    timestamps = datetime.timedelta(seconds=int("".join(div.strings)))
                    timestamps_a.append(timestamps)
                periods_a = list(zip(titles_a, timestamps_a))
            if match_list:
                periods_m = []
                transcriptions = []
                for i, m in enumerate(match_list):
                    chaptitle, timestamp = m.groups()
                    th, tm, ts = timestamp.split(":")
                    periods_m.append((chaptitle, datetime.timedelta(seconds=int(th)*3600 + int(tm)*60 + int(ts))))
                    b, e = m.span()
                    if i+1 < len(match_list):
                      transcriptions.append(full_tr[e:match_list[i+1].span()[0]].strip())
                    else:
                      transcriptions.append(full_tr[e:match_end.span()[0]].strip())
            if has_chap and match_list:
                bools_checks_t = [ta == tm for (ca, ta), (cm, tm) in zip(periods_a, periods_m)]
                bools_checks_c = [ca in cm for (ca, ta), (cm, tm) in zip(periods_a, periods_m)]
                if not all(bools_checks_t):
                    print(f"\t[{eid + 1}/{len(row['Sessions'])}]{d['number']}:{d['title']}\n\t{d['url']}")
                    print("\tWarning: Chapters timestamps not match with hyperlink")
                    print([(ta, tm) for (ca, ta), (cm, tm), b in zip(periods_a, periods_m, bools_checks_t) if not b])
                if not all(bools_checks_c):
                    print(f"\t[{eid + 1}/{len(row['Sessions'])}]{d['number']}:{d['title']}\n\t{d['url']}")
                    print("\tWarning: Chapters titles not match with hyperlink")
                    print([(ca, cm) for (ca, ta), (cm, tm), b in zip(periods_a, periods_m, bools_checks_c) if not b])
                periods = periods_m
            else:
                print(f"\t[{eid + 1}/{len(row['Sessions'])}]{d['number']}:{d['title']}\n\t{d['url']}")
                if match_list:
                    periods = periods_m
                    print("\tWarning: Chapters not verified with hyperlink")
                elif has_chap:
                    periods = periods_a
                    transcriptions = [" ".join([s.strip() for s in tr[3:-4]])]
                    print("\tWarning: Chapters not link with transcription")
                else: 
                    transcriptions = [" ".join([s.strip() for s in tr[3:-4]])]
                    print("\tWarning: Without chapters")
                transcriptions = transcriptions if transcriptions and not transcriptions == list(['']) else None

        if video is None:
            print(f"\t[{eid + 1}/{len(row['Sessions'])}]{d['number']}:{d['title']}\n\t{d['url']}")
            print("\tWarning: Without video")
        if transcriptions and not periods:
            periods = [(d["title"], pd.NaT)]
        return [sid, eid, row["Course Number"], d["number"], d["title"], 
                periods if periods else None,
                transcriptions, 
                url, description, duration, video, resources]
    except Exception as e:
        print(f"Sid : {sid} eid : {eid}")
        print(url)
        print(match_list)
        print(match_end)
        print(tr[-10:])
        print("Error:", e)
        raise(e)

# %%
data = []
chapreg = re.compile(r"(.*)\[(\d+\:\d+\:\d+)\]")
for sid, row in series_df.iterrows():
    print(f"[{sid + 1}/{series_df.shape[0]}]{row['Course Number']}:{row['Serie Name']}\n{row['Url']}")
    for eid, d in enumerate(row["Sessions"]):
        data.append(create_row(sid, row, eid, d))
columns = ["Sid", "N In Series", "Course Number", "Number In Series", "Title", "Chapters",
           "Transcriptions", "Url", "Description", "Duration", "Video", "Ressources"]
episodes_df = pd.DataFrame(data=data, columns=columns)
episodes_df.index.name = "Eid"
episodes_df["Corpus"] = "yaleocw"
# Out:
# [1/40]AFAM 162:African American History: From Emancipation to the Present
# https://oyc.yale.edu/african-american-studies/afam-162
# 	[1/25]Lecture 1:Dawn of Freedom
# 	https://oyc.yale.edu/african-american-studies/afam-162/lecture-1
# 	Warning: Chapters titles not match with hyperlink
# [("Frederick Douglass' Speech, Delivered to Abolitionist Friends in 1852", 'Chapter 1. Frederick Douglass’ Speech, Delivered to Abolitionist Friends in 1852 '), (' What Does It Mean to Be American?', 'Chapter 2. What does it mean to be American? ')]
# 	[2/25]Lecture 2:Dawn of Freedom (continued)
# 	https://oyc.yale.edu/african-american-studies/afam-162/lecture-2
# 	Warning: Chapters titles not match with hyperlink
# [(' Frances Ellen Watkins Harper Poem: "Bury Me in a Free Land"', 'Chapter 2. Frances Ellen Watkins Harper Poem: “Bury Me in a Free Land” ')]
# 	[3/25]Lecture 3:Reconstruction
# 	https://oyc.yale.edu/african-american-studies/afam-162/lecture-3
# 	Warning: Chapters titles not match with hyperlink
# [(" The Freedmen's Bureau", 'Chapter 6. The Freedmen’s Bureau ')]
# 	[4/25]Lecture 4:Reconstruction (continued)
# 	https://oyc.yale.edu/african-american-studies/afam-162/lecture-4
# 	Warning: Chapters titles not match with hyperlink
# [('Billie Holliday Song: "Strange Fruit"', 'Chapter 1. Billie Holliday Song: Strange Fruit '), (' Forces Used to Eliminate the Black Vote', 'Chapter 3. Forces used to Eliminate the Black Vote '), (' Lynching: The Ultimate form of Racial Harassment', 'Chapter 4. Lynching: The Ultimate Form of Racial Harassment ')]
# 	[6/25]Lecture 6:Uplift, Accommodation, and Assimilation (continued)
# 	https://oyc.yale.edu/african-american-studies/afam-162/lecture-6
# 	Warning: Chapters titles not match with hyperlink
# [("The Chronological Context for Today's Lecture", 'Chapter 1. The Chronological Context for Today’s Lecture '), (' Booker T. Washington and the Politics of Accomodation and Assimilation', 'Chapter 2. Booker T. Washington and the Politics of Accommodation and Assimilation '), (' W.E.B. Du Bois and the Politics of Accomodation and Assimilation', 'Chapter 3. W.E.B. Du Bois and the Politics of Accommodation and Assimilation ')]
# 	[7/25]Lecture 7:Migration and Urbanization
# 	https://oyc.yale.edu/african-american-studies/afam-162/lecture-7
# 	Warning: Chapters titles not match with hyperlink
# [('Sterling Brown Poem: "Old Lem"', 'Chapter 1. Sterling Brown Poem: “Old Lem” '), (' Organizations the Focused on the Quality of Black Life', 'Chapter 2. Organizations that Focused on the Quality of Black Life '), (' D.W. Griffith Film: "The Birth of a Nation"', 'Chapter 4. D.W. Griffith Film: “The Birth of a Nation” ')]
# 	[8/25]Lecture 8:Migration and Urbanization (continued)
# 	https://oyc.yale.edu/african-american-studies/afam-162/lecture-8
# 	Warning: Chapters titles not match with hyperlink
# [('W.E.B. Du Bois Editorial: "Close Ranks"', 'Chapter 1. W.E.B. Du Bois Editorial: “Close Ranks” '), (" The Start of World War I and Du Bois' Call to Close Ranks", 'Chapter 4. The Start of World War I and Du Bois’ Call to Close Ranks '), (' W.E.B. Du Bois Editorial: "Returning Soldiers"', 'Chapter 5. W.E.B. Du Bois Editorial: “Returning Soldiers” ')]
# 	[10/25]Lecture 10:The New Negroes (continued)
# 	https://oyc.yale.edu/african-american-studies/afam-162/lecture
# 	https://oyc.yale.edu/african-american-studies/afam-162/lecture-21
# 	Warning: Chapters titles not match with hyperlink
# [(' Johnnie Tillman: "Welfare is a Woman\'s Issue"', 'Chapter 3. Johnnie Tillman: “Welfare is a Woman’s Issue” '), (' Shirley Chisholm Declares Her Candidacy for President', 'Chapter 5. Shirley Chisholm Declares her Candidacy for President ')]
# 	[22/25]Lecture 22:Public Policy and Presidential Politics
# 	https://oyc.yale.edu/african-american-studies/afam-162/lecture-22
# 	Warning: Chapters titles not match with hyperlink
# [(" The Political and Social Milieu around President Nixon's and Ford's Administrations", 'Chapter 5. The Political and Social Milieu around President Nixon and Ford’s Administrations '), (" The Political and Social Milieu around President Jimmy Carter's Administration", 'Chapter 6. The Political and Social Milieu around President Jimmy Carter’s Administration '), (" The Political and Social Milieu around President Ronald Reagan's Administration", 'Chapter 7. The Political and Social Milieu around President Ronald Reagan’s Administration ')]
# 	[23/25]Lecture 23:Public Policy and Presidential Politics (continued)
# 	https://oyc.yale.edu/african-american-studies/afam-162/lecture-23
# 	Warning: Chapters titles not match with hyperlink
# [(' Bernhand Goetz, the "Subway Vigilante"', 'Chapter 2. Bernhand Goetz, the “Subway Vigilante” '), (' Senator Jesse Helms\' "Angry Hands" Advertisement', 'Chapter 6. Senator Jesse Helms’ “Angry Hands” Advertisement ')]
# 	[24/25]Lecture 24:Who Speaks for the Race?
# 	https://oyc.yale.edu/african-american-studies/afam-162/lecture-24
# 	Warning: Chapters titles not match with hyperlink
# [("Bill Clinton's and Lani Guinier", 'Chapter 1. Bill Clinton and Lani Guinier ')]
# 	[25/25]Lecture 25:Who Speaks for the Race? (continued)
# 	https://oyc.yale.edu/african-american-studies/afam-162/lecture-25
# 	Warning: Chapters titles not match with hyperlink
# [(' How Is Race Used?', 'Chapter 3. How is Race Used? ')]
# [2/40]AMST 246:Hemingway, Fitzgerald, Faulkner
# https://oyc.yale.edu/american-studies/amst-246
# 	[2/25]Lecture 2:Hemingway's In Our Time
# 	https://oyc.yale.edu/american-studies/amst-246/lecture-2
# 	Warning: Chapters timestamps not match with hyperlink
# [(datetime.timedelta(seconds=2150), datetime.timedelta(seconds=2151)), (datetime.timedelta(seconds=2922), datetime.timedelta(seconds=2923))]
# 	[3/25]Lecture 3:Hemingway's In Our Time, Part II
# 	https://oyc.yale.edu/american-studies/amst-246/lecture-3
# 	Warning: Chapters timestamps not match with hyperlink
# [(datetime.timedelta(seconds=326), datetime.timedelta(seconds=324)), (datetime.timedelta(seconds=771), datetime.timedelta(seconds=769)), (datetime.timedelta(seconds=1512), datetime.timedelta(seconds=1510)), (datetime.timedelta(seconds=1699), datetime.timedelta(seconds=1677)), (datetime.timedelta(seconds=2293), datetime.timedelta(seconds=2280)), (datetime.timedelta(seconds=2424), datetime.timedelta(seconds=2423))]
# 	[6/25]Lecture 6:Faulkner's The Sound and the Fury
# 	https://oyc.yale.edu/american-studies/amst-246/lecture-6
# 	Warning: Chapters timestamps not match with hyperlink
# [(datetime.timedelta(seconds=1887), datetime.timedelta(seconds=2271))]
# 	[6/25]Lecture 6:Faulkner's The Sound and the Fury
# 	https://oyc.yale.edu/american-studies/amst-246/lecture-6
# 	Warning: Chapters titles not match with hyperlink
# [(' Images of Faulkner’s Oxford, Mississippi ', 'Chapter 5. Taxonomies of Mental Deficiency '), (' The Genesis of The Sound and the Fury ', 'Chapter 6. The Subjectivity of “A Tale Told By An Idiot” '), (' Idiocy as Innocence in Benjy’s Section ', 'Chapter 7. Freud and the Sense of Smell '), (' Faulkner and John Locke ', 'Chapter 8. The Sense of Smell as an Index to Sexual Innocence '), (' Taxonomies of Mental Deficiency ', 'Chapter 9. The Syntactic Consequences of Losing Caddy '), (' The Subjectivity of “A Tale Told By An Idiot”', 'Chapter 10. Sheilding Benjy through Narrative ')]
# 	[7/25]Lecture 7:Faulkner's The Sound and the Fury, Part II
# 	https://oyc.yale.edu/american-studies/amst-246/lecture-7
# 	Warning: Chapters titles not match with hyperlink
# [(" Benjy's Caddy, Quentin’s Caddy", 'Chapter 4. Benjy’s Caddy, Quentin’s Caddy ')]
# 	[10/25]Lecture 10:Hemingway's To Have and Have Not
# 	https://oyc.yale.edu/american-studies/amst-246/lecture-10
# 	Warning: Chapters timestamps not match with hyperlink
# [(datetime.timedelta(seconds=1005), datetime.timedelta(seconds=1006)), (datetime.timedelta(seconds=1401), datetime.timedelta(seconds=1402)), (datetime.timedelta(seconds=2740), datetime.timedelta(seconds=2741))]
# 	[11/25]Lecture 11:Hemingway's To Have and Have Not, Part II
# 	https://oyc.yale.edu/american-studies/amst-246/lecture-11
# 	Warning: Chapters titles not match with hyperlink
# [(" Harry's Loss of Choice as a “Have Not” ", 'Chapter 7: Harry’s Loss of Choice as a “Have Not” ')]
# 	[12/25]Lecture 12:Fitzgerald's Short Stories
# 	https://oyc.yale.edu/american-studies/amst-246/lecture-12
# 	Warning: Chapters timestamps not match with hyperlink
# [(datetime.timedelta(seconds=265), datetime.timedelta(seconds=266)), (datetime.timedelta(seconds=879), datetime.timedelta(seconds=880)), (datetime.timedelta(seconds=1374), datetime.timedelta(seconds=1375)), (datetime.timedelta(seconds=2434), datetime.timedelta(seconds=2435))]
# 	[13/25]Lecture 13:Faulkner's As I Lay Dying
# 	https://oyc.yale.edu/american-studies/amst-246/lecture-13
# 	Warning: Chapters timestamps not match with hyperlink
# [(datetime.timedelta(seconds=275), datetime.timedelta(seconds=276)), (datetime.timedelta(seconds=939), datetime.timedelta(seconds=941)), (datetime.timedelta(seconds=1227), datetime.timedelta(seconds=1228)), (datetime.timedelta(seconds=2290), datetime.timedelta(seconds=1816)), (datetime.timedelta(seconds=2305), datetime.timedelta(seconds=2290)), (datetime.timedelta(seconds=2607), datetime.timedelta(seconds=2609))]
# 	[14/25]Lecture 14:Faulkner's As I Lay Dying, Part II
# 	https://oyc.yale.edu/american-studies/amst-246/lecture-14
# 	Warning: Chapters timestamps not match with hyperlink
# [(datetime.timedelta(seconds=589), datetime.timedelta(seconds=590)), (datetime.timedelta(seconds=1703), datetime.timedelta(seconds=1704)), (datetime.timedelta(seconds=2063), datetime.timedelta(seconds=2064)), (datetime.timedelta(seconds=2531), datetime.timedelta(seconds=2533))]
# 	[14/25]Lecture 14:Faulkner's As I Lay Dying, Part II
# 	https://oyc.yale.edu/american-studies/amst-246/lecture-14
# 	Warning: Chapters titles not match with hyperlink
# [(' Affinities with Animals in As I Lay Dying ', 'Chapter 4: \xa0Affinities with Animals in As I Lay Dying '), (' Mules, epic and tragic  ', 'Chapter 5: \xa0Mules, epic and tragic \xa0')]
# 	[15/25]Lecture 15:Faulkner's As I Lay Dying, Part III
# 	https://oyc.yale.edu/american-studies/amst-246/lecture-15
# 	Warning: Chapters timestamps not match with hyperlink
# [(datetime.timedelta(seconds=1488), datetime.timedelta(seconds=1728))]
# 	[16/25]Lecture 16:Hemingway's For Whom the Bell Tolls
# 	https://oyc.yale.edu/american-studies/amst-246/lecture-16
# 	Warning: Chapters timestamps not match with hyperlink
# [(datetime.timedelta(seconds=152), datetime.timedelta(seconds=153)), (datetime.timedelta(seconds=936), datetime.timedelta(seconds=937)), (datetime.timedelta(seconds=1121), datetime.timedelta(seconds=1122)), (datetime.timedelta(seconds=1536), datetime.timedelta(seconds=1537)), (datetime.timedelta(seconds=2696), datetime.timedelta(seconds=2697))]
# 	[16/25]Lecture 16:Hemingway's For Whom the Bell Tolls
# 	https://oyc.yale.edu/american-studies/amst-246/lecture-16
# 	Warning: Chapters titles not match with hyperlink
# [('Donne’s “For Whom the Bell Tolls” [00:00:00]', 'Chapter 1: Donne’s “For Whom the Bell Tolls” ')]
# 	[17/25]Lecture 17:Hemingway's For Whom the Bell Tolls, Part II
# 	https://oyc.yale.edu/american-studies/amst-246/lecture-17
# 	Warning: Chapters timestamps not match with hyperlink
# [(datetime.timedelta(seconds=193), datetime.timedelta(seconds=194)), (datetime.timedelta(seconds=1120), datetime.timedelta(seconds=1121)), (datetime.timedelta(seconds=2070), datetime.timedelta(seconds=2071)), (datetime.timedelta(seconds=2230), datetime.timedelta(seconds=2231)), (datetime.timedelta(seconds=2395), datetime.timedelta(seconds=2396))]
# 	[18/25]Lecture 18:Hemingway's For Whom the Bell Tolls, Part III
# 	https://oyc.yale.edu/american-studies/amst-246/lecture-18
# 	Warning: Chapters timestamps not match with hyperlink
# [(datetime.timedelta(seconds=580), datetime.timedelta(seconds=579)), (datetime.timedelta(seconds=1504), datetime.timedelta(seconds=1503)), (datetime.timedelta(seconds=1778), datetime.timedelta(seconds=1777)), (datetime.timedelta(seconds=2691), datetime.timedelta(days=1, seconds=75106))]
# 	[19/25]Lecture 19:Hemingway's For Whom the Bell Tolls, Part IV
# 	https://oyc.yale.edu/american-studies/amst-246/lecture-19
# 	Warning: Chapters timestamps not match with hyperlink
# [(datetime.timedelta(seconds=280), datetime.timedelta(seconds=273)), (datetime.timedelta(seconds=919), datetime.timedelta(seconds=912)), (datetime.timedelta(seconds=1302), datetime.timedelta(seconds=1296)), (datetime.timedelta(seconds=1494), datetime.timedelta(seconds=1488)), (datetime.timedelta(seconds=2039), datetime.timedelta(seconds=2033)), (datetime.timedelta(seconds=2432), datetime.timedelta(seconds=2425))]
# 	[20/25]Lecture 20:Fitzgerald's Tender Is the Night
# 	https://oyc.yale.edu/american-studies/amst-246/lecture-20
# 	Warning: Chapters timestamps not match with hyperlink
# [(datetime.timedelta(seconds=509), datetime.timedelta(seconds=417)), (datetime.timedelta(seconds=722), datetime.timedelta(seconds=630)), (datetime.timedelta(seconds=1080), datetime.timedelta(seconds=989)), (datetime.timedelta(seconds=1640), datetime.timedelta(seconds=1548)), (datetime.timedelta(seconds=1971), datetime.timedelta(seconds=1880)), (datetime.timedelta(seconds=2360), datetime.timedelta(seconds=2268)), (datetime.timedelta(seconds=2619), datetime.timedelta(seconds=2527))]
# 	[21/25]Lecture 21:Fitzgerald's Tender is the Night, Part II
# 	https://oyc.yale.edu/american-studies/amst-246/lecture-21
# 	Warning: Chapters timestamps not match with hyperlink
# [(datetime.timedelta(0), datetime.timedelta(seconds=882)), (datetime.timedelta(seconds=652), datetime.timedelta(seconds=623)), (datetime.timedelta(seconds=1020), datetime.timedelta(seconds=972)), (datetime.timedelta(seconds=1451), datetime.timedelta(seconds=1403)), (datetime.timedelta(seconds=1798), datetime.timedelta(seconds=1750)), (datetime.timedelta(seconds=2190), datetime.timedelta(seconds=2165)), (datetime.timedelta(seconds=2450), datetime.timedelta(seconds=2402)), (datetime.timedelta(seconds=2669), datetime.timedelta(seconds=2621)), (datetime.timedelta(seconds=2938), datetime.timedelta(seconds=2889))]
# 	[22/25]Lecture 22:Faulkner's Light in August
# 	https://oyc.yale.edu/american-studies/amst-246/lecture-22
# 	Warning: Chapters timestamps not match with hyperlink
# [(datetime.timedelta(seconds=2359), datetime.timedelta(seconds=2299))]
# 	[23/25]Lecture 23:Faulkner's Light in August, Part II
# 	https://oyc.yale.edu/american-studies/amst-246/lecture-23
# 	Warning: Chapters timestamps not match with hyperlink
# [(datetime.timedelta(seconds=270), datetime.timedelta(seconds=271))]
# 	[23/25]Lecture 23:Faulkner's Light in August, Part II
# 	https://oyc.yale.edu/american-studies/amst-246/lecture-23
# 	Warning: Chapters titles not match with hyperlink
# [(' Political Theology of the Neighbor ', 'Chapter 2: \xa0Political Theology of the Neighbor '), (' Alternation between Joe Christmas and Lena Grove ', 'Chapter 7: \xa0Alternation between Joe Christmas and Lena Grove ')]
# 	[24/25]Lecture 24:Faulkner's Light in August, Part III
# 	https://oyc.yale.edu/american-studies/amst-246/lecture-24
# 	Warning: Chapters titles not match with hyperlink
# [(' Under Duress: Joe Brown uses the Word “Nigger” ', 'Chapter 2: \xa0Under Duress: Joe Brown uses the Word “Nigger” '), (' The Two Faces of Hightower  ', 'Chapter 6: The Two Faces of Hightower \xa0'), (' Bobbie’s Involuntary Use of the World “Nigger”  ', 'Chapter 8: Bobbie’s Involuntary Use of the World “Nigger”\xa0 ')]
# 	[25/25]Lecture 25:Faulkner's Light in August, Part IV
# 	https://oyc.yale.edu/american-studies/amst-246/lecture-25
# 	Warning: Chapters timestamps not match with hyperlink
# [(datetime.timedelta(0), datetime.timedelta(seconds=360))]
# 	[25/25]Lecture 25:Faulkner's Light in August, Part IV
# 	https://oyc.yale.edu/american-studies/amst-246/lecture-25
# 	Warning: Chapters titles not match with hyperlink
# [(' Multitude: Faulkner’s Kindness of Strangers  ', 'Chapter 9: Multitude: Faulkner’s Kindness of Strangers \xa0')]
# [3/40]ASTR 160:Frontiers and Controversies in Astrophysics
# https://oyc.yale.edu/astronomy/astr-160
# 	[1/29]Lecture 1:Introduction
# 	https://oyc.yale.edu/astronomy/astr-160/lecture-1
# 	Warning: Chapters titles not match with hyperlink
# [(" From Newton's Laws of Motion to the Theory of Everything", 'Chapter 5. From Newton’s Laws of Motion to the Theory of Everything '), (" The Newtonian Modification of Kepler's Third Law", 'Chapter 6. The Newtonian Modification of Kepler’s Third Law ')]
# 	[4/29]Lecture 4:Discovering Exoplanets: Hot Jupiters
# 	https://oyc.yale.edu/astronomy/astr-160/lecture-4
# 	Warning: Chapters titles not match with hyperlink
# [(' 51 Pegasus and "Hot Jupiters"', 'Chapter 4. 51 Pegasus and “Hot Jupiters” ')]
# 	[8/29]Update 1:The Kepler Mission
# 	https://oyc.yale.edu/astronomy/astr-160/update-1
# 	Warning: Without chapters
# 	[9/29]Exam 1:Midterm Exam 1
# 	https://oyc.yale.edu/astronomy/astr-160/exam-1
# 	Warning: Without video
# 	[13/29]Lecture 11:Special and General Relativity (cont.)
# 	https://oyc.yale.edu/astronomy/astr-160/lecture-11
# 	Warning: Chapters titles not match with hyperlink
# [("Lessons from Einstein's Discovery of Relativity", 'Chapter 1. Lessons from Einstein’s Discovery of Relativity ')]
# 	[15/29]Lecture 13:Stellar Mass Black Holes (cont.)
# 	https://oyc.yale.edu/astronomy/astr-160/lecture-13
# 	Warning: Chapters timestamps not match with hyperlink
# [(datetime.timedelta(0), datetime.timedelta(seconds=944)), (datetime.timedelta(seconds=944), datetime.timedelta(seconds=1364)), (datetime.timedelta(seconds=1364), datetime.timedelta(seconds=1891)), (datetime.timedelta(seconds=1891), datetime.timedelta(seconds=2714))]
# 	[15/29]Lecture 13:Stellar Mass Black Holes (cont.)
# 	https://oyc.yale.edu/astronomy/astr-160/lecture-13
# 	Warning: Chapters titles not match with hyperlink
# [('Defining Black Holes in Terms of the Schwarzschild Radius', 'Chapter 2. Perihelions and Deflection of Light '), (' Perihelions and Deflection of Light', 'Chapter 3. Hunting Eclipses '), (' Hunting Eclipses', 'Chapter 4. Gravitational Redshift '), (' Gravitational Redshift', 'Chapter 5. Gravitational Waves ')]
# 	[16/29]Lecture 14:Pulsars
# 	https://oyc.yale.edu/astronomy/astr-160/lecture-14
# 	Warning: Chapters timestamps not match with hyperlink
# [(datetime.timedelta(seconds
# 	Warning: Chapters timestamps not match with hyperlink
# [(datetime.timedelta(seconds=149), datetime.timedelta(seconds=148)), (datetime.timedelta(seconds=812), datetime.timedelta(seconds=810)), (datetime.timedelta(seconds=1941), datetime.timedelta(seconds=1939)), (datetime.timedelta(seconds=2398), datetime.timedelta(seconds=2394))]
# 	[25/27]Lecture 24:Biomedical Engineers and Cancer
# 	https://oyc.yale.edu/biomedical-engineering/beng-100/lecture-24
# 	Warning: Chapters timestamps not match with hyperlink
# [(datetime.timedelta(seconds=235), datetime.timedelta(seconds=236)), (datetime.timedelta(seconds=2087), datetime.timedelta(seconds=2086))]
# 	[26/27]Lecture 25:Biomedical Engineers and Artificial Organs
# 	https://oyc.yale.edu/biomedical-engineering/beng-100/lecture-25
# 	Warning: Chapters timestamps not match with hyperlink
# [(datetime.timedelta(seconds=951), datetime.timedelta(seconds=950)), (datetime.timedelta(seconds=1662), datetime.timedelta(seconds=1661)), (datetime.timedelta(seconds=2633), datetime.timedelta(seconds=2631))]
# without video
# 	[27/27]Exam 2:Final Exam
# 	https://oyc.yale.edu/biomedical-engineering/beng-100/exam-2
# 	Warning: Without chapters
# [5/40]CHEM 125a:Freshman Organic Chemistry I
# https://oyc.yale.edu/chemistry/chem-125a
# 	[1/41]Lecture 1:How Do You Know?
# 	https://oyc.yale.edu/chemistry/chem-125a/lecture-1
# 	Warning: Chapters titles not match with hyperlink
# [(" Bacon's Instauration: Experimentation over Philosophy ", 'Chapter 3. Bacon’s Instauration: Experimentation over Philosophy '), (" Atoms, Molecules, and Hooke's Law ", 'Chapter 5. Atoms, Molecules, and Hooke’s Law ')]
# 	[2/41]Lecture 2:Force Laws, Lewis Structures and Resonance
# 	https://oyc.yale.edu/chemistry/chem-125a/lecture-2
# 	Warning: Chapters timestamps not match with hyperlink
# [(datetime.timedelta(seconds=1302), datetime.timedelta(seconds=1303))]
# 	[4/41]Lecture 4:Coping with Smallness and Scanning Probe Microscopy
# 	https://oyc.yale.edu/chemistry/chem-125a/lecture-4
# 	Warning: Chapters titles not match with hyperlink
# [(' Scanning Probe Microscopy: Feeling out Electron Pairs ', 'Chapter 3. Scanning Probe Microscopy: Feeling out and Seeing Electron Pairs ')]
# 	[7/41]Lecture 7:Quantum Mechanical Kinetic Energy
# 	https://oyc.yale.edu/chemistry/chem-125a/lecture-7
# 	Warning: Chapters timestamps not match with hyperlink
# [(datetime.timedelta(seconds=2005), datetime.timedelta(seconds=2004))]
# 	[9/41]Lecture 9:Chladni Figures and One-Electron Atoms
# 	https://oyc.yale.edu/chemistry/chem-125a/lecture-9
# 	Warning: Chapters timestamps not match with hyperlink
# [(datetime.timedelta(seconds=1925), datetime.timedelta(seconds=1926))]
# 	[9/41]Lecture 9:Chladni Figures and One-Electron Atoms
# 	https://oyc.yale.edu/chemistry/chem-125a/lecture-9
# 	Warning: Chapters titles not match with hyperlink
# [(' Addressing Multi-Dimensional Problems: Chladni’s “Acoustics” ', 'Chapter 2. Addressing Multi-Dimensional Problems: Chladni’s Acoustics ')]
# 	[10/41]Lecture 10:Reality and the Orbital Approximation
# 	https://oyc.yale.edu/chemistry/chem-125a/lecture-10
# 	Warning: Chapters timestamps not match with hyperlink
# [(datetime.timedelta(seconds=848), datetime.timedelta(seconds=847))]
# 	[10/41]Lecture 10:Reality and the Orbital Approximation
# 	https://oyc.yale.edu/chemistry/chem-125a/lecture-10
# 	Warning: Chapters titles not match with hyperlink
# [('“Atom-in-a-Box” Plots: Assessing Probability Density ', 'Chapter 1. Atom-in-a-Box Plots: Assessing Probability Density ')]
# 	[11/41]Exam 1:Midterm Exam 1
# 	https://oyc.yale.edu/chemistry/chem-125a/exam-1
# 	Warning: Without video
# 	[12/41]Lecture 11:Orbital Correction and Plum-Pudding Molecules
# 	https://oyc.yale.edu/chemistry/chem-125a/lecture-11
# 	Warning: Chapters timestamps not match with hyperlink
# [(datetime.timedelta(seconds=1847), datetime.timedelta(seconds=1848))]
# 	[13/41]Lecture 12:Overlap and Atom-Pair Bonds
# 	https://oyc.yale.edu/chemistry/chem-125a/lecture
# 	https://oyc.yale.edu/chemistry/chem-125b/lecture-19
# 	Warning: Chapters titles not match with hyperlink
# [(' How Bad is "Forbidden"? Opening Dewar Benzene', 'Chapter 4. How Bad is “Forbidden”? Opening Dewar Benzene ')]
# 	[20/38]Lecture 20:Electronic and Vibrational Spectroscopy
# 	https://oyc.yale.edu/chemistry/chem-125b/lecture-20
# 	Warning: Chapters titles not match with hyperlink
# [(" Infrared Spectra, Hooke's Law, and Vibrational Frequency", 'Chapter 3. Infrared Spectra, Hooke’s Law, and Vibrational Frequency '), (' Why IR Is Complicated: Coupled Oscillators and Normal Modes', 'Chapter 4. Why IR is Complicated: Coupled Oscillators and Normal Modes ')]
# 	[35/38]Lecture 35:Acyl Insertions and α-Reactivity
# 	https://oyc.yale.edu/chemistry/chem-125b/lecture-35
# 	Warning: Chapters titles not match with hyperlink
# [(' α\ufeff-Acidity', 'Chapter 2. α-Acidity '), (' α-Alkylation\ufeff-Halogenation', 'Chapter 4. α-Alkylation-Halogenation '), (' α\ufeff-Alkylation', 'Chapter 5. α-Alkylation ')]
# 	[37/38]Lecture 37:Proving the Configuration of Glucose and Synthesizing Two Unnatural Products
# 	https://oyc.yale.edu/chemistry/chem-125b/lecture-37
# 	Warning: Chapters titles not match with hyperlink
# [(" Glucose Constitution from van't Hoff to the Kiliani-Fischer Synthesis", 'Chapter 2. Glucose Constitution from van’t Hoff to the Kiliani-Fischer Synthesis '), (" Fischer's Osazones, Fischer's Projection, and Fischer's Evidence", 'Chapter 3. Fischer’s Osazones, Fischer’s Projection, and Fischer’s Evidence '), (" Fischer's Proof of the Configuration of Glucose", 'Chapter 4. Fischer’s Proof of the Configuration of Glucose ')]
# 	[38/38]Lecture 38:Review: Synthesis of Cortisone
# 	https://oyc.yale.edu/chemistry/chem-125b/lecture-38
# 	Warning: Chapters titles not match with hyperlink
# [(" Woodward's Total Synthesis of Cortisone", 'Chapter 2. Woodward’s Total Synthesis of Cortisone ')]
# [7/40]CLCV 205:Introduction to Ancient Greek History
# https://oyc.yale.edu/classics/clcv-205
# 	[2/24]Lecture 2:The Dark Ages
# 	https://oyc.yale.edu/classics/clcv-205/lecture-2
# 	Warning: Chapters titles not match with hyperlink
# [(' Cultural Unity, Agriculture, Religio us Authority', 'Chapter 4. Cultural Unity, Agriculture, Religious Authority ')]
# 	[3/24]Lecture 3:The Dark Ages (cont.)
# 	https://oyc.yale.edu/classics/clcv-205/lecture-3
# 	Warning: Chapters titles not match with hyperlink
# [(" The Society Described in Homer's Poems", 'Chapter 2. The Society Described in Homer’s Poems ')]
# 	[4/24]Lecture 4:The Rise of the Polis
# 	https://oyc.yale.edu/classics/clcv-205/lecture-4
# 	Warning: Chapters titles not match with hyperlink
# [('Defining "Arête"', 'Chapter 1. Defining\xa0Arete\xa0'), (' The Rise of the "Polis"', 'Chapter 3. The Rise of the\xa0Polis\xa0'), (' The Features and Importance of the "Polis"', 'Chapter 4. The Features and Importance of the\xa0Polis\xa0')]
# 	[5/24]Lecture 5:The Rise of the Polis (cont.)
# 	https://oyc.yale.edu/classics/clcv-205/lecture-5
# 	Warning: Chapters titles not match with hyperlink
# [('The "Polis" in Hesiod\'s Work', 'Chapter 1. The\xa0Polis\xa0in Hesiod’s Work '), (' Greek Farmers and the Function of the "Polis"', 'Chapter 3. Greek Farmers and the Function of the\xa0Polis\xa0')]
# 	https://oyc.yale.edu/spanish-and-portuguese/span-300/lecture-21
# 	Warning: Chapters titles not match with hyperlink
# [(" Sancho's Fall into the Pit", 'Chapter 3. Sancho’s Fall into the Pit ')]
# 	[22/24]Lecture 22:Don Quixote, Part II: Chapters LIV-LXX (cont.)
# 	https://oyc.yale.edu/spanish-and-portuguese/span-300/lecture-22
# 	Warning: Chapters titles not match with hyperlink
# [(' Avellaneda’s Spurious “Quixote” ', 'Chapter 2. Avellaneda’s Spurious Quixote ')]
# 	[23/24]Lecture 23:Don Quixote, Part II: Chapters LXXI-LXXIV
# 	https://oyc.yale.edu/spanish-and-portuguese/span-300/lecture-23
# 	Warning: Chapters titles not match with hyperlink
# [(' Unamuno’s, Borges’s and Picasso’s Visions of “Don Quixote” ', 'Chapter 5. Unamuno’s, Borges’s and Picasso’s Visions of Don Quixote ')]
# 	[24/24]Lecture 24:Don Quixote, Part II: Chapters LXXI-LXXIV (cont.)
# 	https://oyc.yale.edu/spanish-and-portuguese/span-300/lecture-24
# 	Warning: Chapters titles not match with hyperlink
# [(' Remarks on “Exemplary Novels” ', 'Chapter 2. Remarks on Exemplary Novels '), (' “The Deceitful Marriage”: Working Backwards to Deconstruct Marriage as Social Institution ', 'Chapter 3. The Deceitful Marriage: Working Backwards to Deconstruct Marriage as Social Institution '), (' “The Dogs Colloquy”: A Picaresque Autobiography Skirting the Supernatural ', 'Chapter 4. The Dogs Colloquy: A Picaresque Autobiography Skirting the Supernatural ')]

# %%
# match_list = create_row(1, series_df.loc[1], 4, series_df.loc[1, "Sessions"][4])

# %%
# [m.groups() for m in match_list], match_list

# %%
episodes_df.loc[lambda df: [not d for d in df["Chapters"]]]
# Out:
#      Sid  N In Series Course Number Number In Series  \
# Eid
# 58     2            8      ASTR 160           Exam 1
# 68     2           18      ASTR 160           Exam 2
# 94     3           15      BENG 100           Exam 1
# 105    3           26      BENG 100           Exam 2
# 116    4           10     CHEM 125a           Exam 1
# 126    4           20     CHEM 125a           Exam 2
# 137    4           31     CHEM 125a           Exam 3
# 146    4           40     CHEM 125a           Exam 4
# 230    7           21       EEB 122           Exam 1
# 246    7           37       EEB 122           Exam 2
# 257    8           10      ECON 252           Exam 1
# 264    8           17      ECON 252           Exam 2
# 275    8           28      ECON 252           Exam 3
# 283    9            7      ECON 252           Exam 1
# 292    9           16      ECON 252           Exam 2
# 301    9           25      ECON 252           Exam 3
# 340   11           12      ECON 159           Exam 1
# 353   11           25      ECON 159           Exam 2
# 390   13           10      ENGL 220           Exam 1
# 402   13           22      ENGL 220           Exam 2
# 428   14           25      ENGL 310           Exam 1
# 455   15           26      ENGL 291           Exam 1
# 490   17           10        GG 140           Exam 1
# 498   17           18        GG 140              Lab
# 500   17           20        GG 140           Exam 2
# 511   17           31        GG 140           Exam 3
# 519   17           39        GG 140       Final Exam
# 572   19           27      HIST 119             Exam
# 632   22           13      HIST 234           Exam 1
# 646   22           27      HIST 234           Exam 2
# 723   26           13      ITAL 310           Exam 1
# 735   26           25      ITAL 310           Exam 2
# 822   30           10      PHYS 200           Exam 1
# 835   30           23      PHYS 200           Exam 2
# 850   31           14      PHYS 201           Exam 1
# 862   31           26      PHYS 201           Exam 2
# 872   32            9      PLSC 270       Lecture 10
# 862   Final Exam covers the second half of the course.             NaT
# 872  Richard Medley, former CEO of the business int...             NaT
# 923             The midterm was administered in class.             NaT
# 924  This lecture provided an overview of brain fun...             NaT
# 927  This lecture covers the reasons people eat wha...             NaT
# 934  The final exam was administered in class. Fina...             NaT
# 995  The midterm exam covers the material from lect...             NaT
#
#                                                  Video  \
# Eid
# 58                                                None
# 68                                                None
# 94   {'url': 'http://FILENAME.mp4', 'captions': '',...
# 105  {'url': 'http://FILENAME.mp4', 'captions': '',...
# 116                                               None
# 126                                               None
# 137                                               None
# 146                                               None
# 230                                               None
# 246                                               None
# 257                                               None
# 264                                               None
# 275                                               None
# 283                                               None
# 292                                               None
# 301                                               None
# 340                                               None
# 353                                               None
# 390                                               None
# 402                                               None
# 428                                               None
# 455                                               None
# 490                                               None
# 498  {'url': 'http://openmedia.yale.edu/projects/co...
# 500                                               None
# 511                                               None
# 519                                               None
# 572                                               None
# 632                                               None
# 646                                               None
# 723                                               None
# 735                                               None
# 822                                               None
# 835                                               None
# 850                                               None
# 862                                               None
# 872                                               None
# 923                                               None
# 924                                               None
# 927                                               None
# 934                                               None
# 995                                               None
#
#                                             Ressources   Corpus
# Eid
# 58   [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 68   [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 94   [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 105  [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 116  [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 126  [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 137  [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 146  [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 230  [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 246  [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 257  [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 264  [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 275  [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 283  [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 292  [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 301  [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 340  [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 353  [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 390  [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 402  [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 428  [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 455  [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 490  [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 498                                               None  yaleocw
# 500  [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 511  [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 519  [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 572  [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 632  [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 646  [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 723  [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 735  [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 822  [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 835  [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 850  [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 862  [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 872                                               None  yaleocw
# 923  [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 924                                               None  yaleocw
# 927                                               None  yaleocw
# 934  [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 995  [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw

# %%
episodes_df
# Out:
#       Sid  N In Series Course Number Number In Series  \
# Eid
# 0       0            0      AFAM 162        Lecture 1
# 1       0            1      AFAM 162        Lecture 2
# 2       0            2      AFAM 162        Lecture 3
# 3       0            3      AFAM 162        Lecture 4
# 4       0            4      AFAM 162        Lecture 5
# ...   ...          ...           ...              ...
# 1053   39           19      SPAN 300       Lecture 20
# 1054   39           20      SPAN 300       Lecture 21
# 1055   39           21      SPAN 300       Lecture 22
# 1056   39           22      SPAN 300       Lecture 23
# 1057   39           23      SPAN 300       Lecture 24
#
#                                                   Title  \
# Eid
# 0                                       Dawn of Freedom
# 1                           Dawn of Freedom (continued)
# 2                                        Reconstruction
# 3                            Reconstruction (continued)
# 4               Uplift, Accommodation, and Assimilation
# ...                                                 ...
# 1053  Don Quixote, Part II: Chapters XXXVI-LIII (cont.)
# 1054             Don Quixote, Part II: Chapters LIV-LXX
# 1055     Don Quixote, Part II: Chapters LIV-LXX (cont.)
# 1056          Don Quixote, Part II: Chapters LXXI-LXXIV
# 1057  Don Quixote, Part II: Chapters LXXI-LXXIV (cont.)
#
#                                                Chapters  \
# Eid
# 0     [(Chapter 1. Frederick Douglass’ Speech, Deliv...
# 1     [(Chapter 1. Introduction and Recap of Last Cl...
# 2     [(Chapter 1. Introduction: The Reconstruction ...
# 3     [(Chapter 1. Billie Holliday Song: Strange Fru...
# 4     [(Chapter 1. Alexander Crummell , 00:00:00, 0:...
# ...                                                 ...
# 1053  [(Chapter 1. Revisiting Major Themes in Don Qu...
# 1054  [(Chapter 1. Improvisation, International Dime...
# 1055  [(Chapter 1. Episodes in Barcelona , 00:00:00,...
# 1056  [(Chapter 1. Humor; Cervantes’s Self Portraits...
# 1057  [(Chapter 1. Cervantes at Death: At Peace with...
#
#                                          Transcriptions  \
# Eid
# 0     [Professor Jonathan Holloway: \n“Fellow citize...
# 1     [Professor Jonathan Holloway:  Yesterday, Mond...
# 2     [Professor Jonathan Holloway:  \n“I know the n...
# 3     [Professor Jonathan Holloway:  I’m going to st...
# 4     [Professor Jonathan Holloway:  Let me begin th...
# ...                                                 ...
# 1053  [Professor Roberto González Echevarría: What i...
# 1054  [Professor Roberto González Echevarría: There ...
# 1055  [Professor Roberto González Echevarría: To me,...
# 1056  [Professor Roberto González Echevarría: As we ...
# 1057  [Professor Roberto González Echevarría: Miguel...
#
#                                                     Url  \
# Eid
# 0     https://oyc.yale.edu/african-american-studies/...
# 1     https://oyc.yale.edu/african-american-studies/...
# 2     https://oyc.yale.edu/african-american-studies/...
# 3     https://oyc.yale.edu/african-american-studies/...
# 4     https://oyc.yale.edu/african-american-studies/...
# ...                                                 ...
# 1053  https://oyc.yale.edu/spanish-and-portuguese/sp...
# 1054  https://oyc.yale.edu/spanish-and-portuguese/sp...
# 1055  https://oyc.yale.edu/spanish-and-portuguese/sp...
# 1056  https://oyc.yale.edu/spanish-and-portuguese/sp...
# 1057  https://oyc.yale.edu/spanish-and-portuguese/sp...
#
#                                             Description        Duration  \
# Eid
# 0     Professor Holloway offers an introduction to t... 00:34:51.489000
# 1     In this lecture, Professor Holloway gives a br... 00:40:56.183578
# 2     Between 1865 and 1877, several plans were deve... 00:48:54.793278
# 3     After the massive cultural shift that the Sout... 00:47:17.548111
# 4     In the closing decades of the 1800s, African A... 00:43:58.413778
# ...                                                 ...             ...
# 1053  According to González Echevarría, Don Quixote’... 00:56:53.124344
# 1054  Three issues related to the impending end of t... 00:55:32.969067
# 1055  As we approach the end of the novel, Cervantes... 00:58:52.892878
# 1056  González Echevarría focuses on the end of the ... 00:59:37.150111
# 1057  Would have Cervantes deserved such recognition... 01:04:54.334689
#
#                                                   Video  \
# Eid
# 0     {'url': 'http://openmedia.yale.edu/projects/co...
# 1     {'url': 'http://openmedia.yale.edu/projects/co...
# 2     {'url': 'http://openmedia.yale.edu/projects/co...
# 3     {'url': 'http://openmedia.yale.edu/projects/co...
# 4     {'url': 'http://openmedia.yale.edu/projects/co...
# ...                                                 ...
# 1053  {'url': 'http://openmedia.yale.edu/projects/co...
# 1054  {'url': 'http://openmedia.yale.edu/projects/co...
# 1055  {'url': 'http://openmedia.yale.edu/projects/co...
# 1056  {'url': 'http://openmedia.yale.edu/projects/co...
# 1057  {'url': 'http://openmedia.yale.edu/projects/co...
#
#                                              Ressources   Corpus
# Eid
# 0     [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 1     [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 2     [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 3     [{'url': 'https://oyc.yale.edu/sites/default/f...  yaleocw
# 4                                                  None  yaleocw
# ...                                                 ...      ...
# 1053                                               None  yaleocw
# 1054                                               None  yaleocw
# 1055                                               None  yaleocw
# 1056                                               None  yaleocw
# 1057                                               None  yaleocw
#
# [1058 rows x 13 columns]

# %%
keep_df = episodes_df.dropna().loc[:, ["Sid", "Transcriptions", "Chapters"]]
chapters_df = []
for sid, epgroup in keep_df.groupby("Sid"):
    for eid, row in epgroup.iterrows():
        attrlist = list(zip(row["Transcriptions"], row["Chapters"]))
        for i, (t, c) in enumerate(attrlist):
            end_timestamp = attrlist[i + 1][1][1] if i < len(attrlist) - 1 else episodes_df.loc[eid].Duration
            print(end_timestamp, c[1])
            duration = end_timestamp - c[1]
            chapters_df.append([eid, sid, i, t, c[0], c[1], end_timestamp, duration])
chapters_df = pd.DataFrame(chapters_df,
                           columns=["Eid", "Sid", "PartN", "Text", "Title", "BeginTimestamp", "EndTimestamp", "Duration"])
chapters_df.index.name = "Cid"
chapters_df["Corpus"] = "yaleocw"
# Out:
# 00:04:44 00:00:00
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-108-777cb5942211> in <module>
#       8             assert c[0] != ' '
#       9             print(end_timestamp, c[1])
# ---> 10             duration = end_timestamp - c[1]
#      11             chapters_df.append([eid, sid, i, t, c[0], c[1], end_timestamp, duration])
#      12 chapters_df = pd.DataFrame(chapters_df,
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
chapters_df

# %%
# @Deprecated reserve for local usage

# series_df["Path"] = None
# episodes_df["Path"] = None
# chapters_df["Path"] = None

# for sid, srow in series_df.iterrows():
#     stag, sname = srow["Course Number"], srow["Serie Name"]
#     stag, sname = re.sub(r"[ /\\]+", r"_", stag), re.sub(r"[ /\\]+", r"_", sname)
#     dirname = os.path.join("data/YaleSeriesCorpus", f"{sid}-{stag}-{sname}")
#     if not os.path.exists(dirname): os.makedirs(dirname)
#     for eid, erow in episodes_df[episodes_df.Sid==sid].iterrows():
#         name = f"{eid}-{erow['N In Series']}-{erow['Title']}"
#         name = re.sub(r"[ /\\]+", r"_", name)
#         subdirname = os.path.join(dirname, name)
#         if not os.path.exists(subdirname): os.makedirs(subdirname)
#         if erow["Transcriptions"]: 
#             transcription = "".join(erow["Transcriptions"])
#             with open(os.path.join(subdirname, "rawtext"), "w") as f:
#                 f.write(transcription)
#         for cid, crow in chapters_df[chapters_df.Eid==eid].iterrows():
#             name = f"{cid}-{crow['PartN']}-{crow['Title']}"
#             name = re.sub(r"[ /\\]+", r"_", name)
#             subsubdirname = os.path.join(subdirname, name)
#             if not os.path.exists(subsubdirname): os.makedirs(subsubdirname)
#             with open(os.path.join(subsubdirname, "rawtext"), "w") as f:
#                 f.write(crow["Text"])

# %%
series_df.to_csv(path_or_buf="data/series.csv", sep='|')
episodes_df.to_csv(path_or_buf="data/episodes.csv", sep='|')
chapters_df.to_csv(path_or_buf="data/chapters.csv", sep='|')

series_df.to_json("data/series.json")
episodes_df.to_json("data/episodes.json")
chapters_df.to_json("data/chapters.json")

series_df.to_pickle("data/series.pickle")
episodes_df.to_pickle("data/episodes.pickle")
chapters_df.to_pickle("data/chapters.pickle")
